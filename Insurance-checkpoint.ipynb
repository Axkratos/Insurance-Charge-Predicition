# %%
medical_charges_url="https://raw.githubusercontent.com/JovianML/opendatasets/master/data/medical-charges.csv"

# %%
from urllib.request import urlretrieve

# %%
urlretrieve(medical_charges_url,'medical.csv')
# Out:
# ('medical.csv', <http.client.HTTPMessage at 0x207d5993590>)

# %%
import pandas as pd

# %%
medical_df=pd.read_csv('medical.csv')

# %%
medical_df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
medical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
medical_df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# From here i am going to use different libraries for data visualization

# %%
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
medical_df.age.describe()
# Out:
# count    1338.000000
# mean       39.207025
# std        14.049960
# min        18.000000
# 25%        27.000000
# 50%        39.000000
# 75%        51.000000
# max        64.000000
# Name: age, dtype: float64

# %%
fig=px.histogram(medical_df,
                x='age',
                marginal='box',
                nbins=47,
                title='Distribution of age')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="8972a781-7c46-4eb4-b566-9172f29641fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8972a781-7c46-4eb4-b566-9172f29641fc")) {                    Plotly.newPlot(                        "8972a781-7c46-4eb4-b566-9172f29641fc",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":47,"offsetgroup":"","orientation":"v","showlegend":false,"x":[19,18,28,33,32,31,46,37,37,60,25,62,23,56,27,19,52,23,56,30,60,30,18,34,37,59,63,55,23,31,22,18,19,63,28,19,62,26,35,60,24,31,41,37,38,55,18,28,60,36,18,21,48,36,40,58,58,18,53,34,43,25,64,28,20,19,61,40,40,28,27,31,53,58
# ...

# %%
fig = px.histogram(medical_df, 
                   x='bmi', 
                   marginal='box', 
                   color_discrete_sequence=['red'], 
                   title='Distribution of BMI (Body Mass Index)')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="c5918826-6f9f-4cfa-969f-59e476e52b32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5918826-6f9f-4cfa-969f-59e476e52b32")) {                    Plotly.newPlot(                        "c5918826-6f9f-4cfa-969f-59e476e52b32",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"bmi=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"red","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[27.9,33.77,33.0,22.705,28.88,25.74,33.44,27.74,29.83,25.84,26.22,26.29,34.4,39.82,42.13,24.6,30.78,23.845,40.3,35.3,36.005,32.4,34.1,31.92,28.025,27.72,23.085,32.775,17.385,36.3,35.6,26.315,28.6,28.31,36.4,20.425,32.965,20.8,36.67,39.9,2
# ...

# %%
fig=px.histogram(medical_df,
                x='charges',
                color='smoker',
                 marginal='box',
                color_discrete_sequence=['green','grey'],
                title='Annual Medical charges')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="a6d79f43-4033-4881-ad9e-beb1f3e055ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a6d79f43-4033-4881-ad9e-beb1f3e055ba")) {                    Plotly.newPlot(                        "a6d79f43-4033-4881-ad9e-beb1f3e055ba",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"smoker=yes<br>charges=%{x}<br>count=%{y}<extra></extra>","legendgroup":"yes","marker":{"color":"green","pattern":{"shape":""}},"name":"yes","offsetgroup":"yes","orientation":"v","showlegend":true,"x":[16884.924,27808.7251,39611.7577,36837.467,37701.8768,38711.0,35585.576,51194.55914,39774.2763,48173.361,38709.176,23568.272,37742.5757,47496.49445,34303.1672,23244.7902,14711.7438,17663.1442,16577.7795,37165.1
# ...

# %%
medical_df.charges.corr(medical_df.age)
# Out:
# 0.2990081933306476

# %%
fig = px.scatter(medical_df, 
                 x='age', 
                 y='charges', 
                 color='smoker', 
                 opacity=0.8, 
                  
                 title='Age vs. Charges')
fig.update_traces(marker_size=5)
fig.show()
# Out:
# <div>                            <div id="89f48c24-5363-4996-b7d7-88d63731b557" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89f48c24-5363-4996-b7d7-88d63731b557")) {                    Plotly.newPlot(                        "89f48c24-5363-4996-b7d7-88d63731b557",                        [{"hovertemplate":"smoker=yes<br>age=%{x}<br>charges=%{y}<extra></extra>","legendgroup":"yes","marker":{"color":"#636efa","opacity":0.8,"symbol":"circle","size":5},"mode":"markers","name":"yes","showlegend":true,"x":[19,62,27,30,34,31,22,28,35,60,36,48,36,58,18,53,20,28,27,22,37,45,57,59,64,56,38,61,20,63,29,44,19,32,34,30,46,42,48,18,30,42,18,63,36,27,35,19,42,40,19,23,63,18,63,54,50,56,19,20,52,19,46,40,50,40,54,59,25,19,47,31,53,43,27,34,45,64,61,52,50,19,26,23
# ...

# %%
smoker_values={'no':0,'yes':1}
smoker_numeric=medical_df.smoker.map(smoker_values)
medical_df.charges.corr(smoker_numeric)
# Out:
# 0.7872514304984767

# %%
non_smoker_df=medical_df[medical_df.smoker=='no']
non_smoker_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# ...   ...     ...     ...       ...    ...        ...          ...
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
#
# [1064 rows x 7 columns]

# %%
plt.title('Age vs Charges')
sns.scatterplot(data=non_smoker_df,x='age',y='charges',alpha=0.7,s=15)
# Out:
# <Axes: title={'center': 'Age vs Charges'}, xlabel='age', ylabel='charges'>

# %% [markdown]
# Now we are having a pattern where we can fit a line. This will be model for non smokers.

# %%
def estimated(ages,w,b):
    return w*ages+b

# %%
w=200
b=500

# %%
ages=non_smoker_df.age

# %%
estimate=estimated(ages,w,b)

# %%
non_smoker_df.charges
# Out:
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
# 5        3756.62160
#            ...
# 1332    11411.68500
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# Name: charges, Length: 1064, dtype: float64

# %%
print(len(ages))
print(len(estimate))
# Out:
# 1064
# 1064

# %%
plt.plot(ages,estimate,'r-o')
plt.xlabel('age')
plt.ylabel('charges')
# Out:
# Text(0, 0.5, 'charges')

# %%
non_smoker_df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# 5      31  female  25.740         0     no  southeast   3756.62160
# ...   ...     ...     ...       ...    ...        ...          ...
# 1332   52  female  44.700         3     no  southwest  11411.68500
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
#
# [1064 rows x 7 columns]

# %% [markdown]
# Now we need to plot this line above age vs charge plot

# %%
target=non_smoker_df.charges
plt.plot(ages,estimate,'r-o')
plt.scatter(ages,target,s=8,alpha=0.8)
plt.xlabel('Age');
plt.ylabel('Charges')
plt.legend(['Estimate','Actual'])

# %%
print(w)
# Out:
# 200

# %%
print(b)
# Out:
# 500

# %% [markdown]
# Here to find the error of our model we need to use loss function

# %%
import numpy as np

# %%
def rmse(targets, predictions):
    return np.sqrt(np.mean(np.square(targets - predictions)))

# %%
def try_parameters(w, b):
    ages = non_smoker_df.age
    target = non_smoker_df.charges
    predictions = estimated(ages, w, b)
    
    plt.plot(ages, predictions, 'r', alpha=0.9);
    plt.scatter(ages, target, s=8,alpha=0.8);
    plt.xlabel('Age');
    plt.ylabel('Charges')
    plt.legend(['Prediction', 'Actual']);
    
    loss = rmse(target, predictions)
    print("RMSE Loss: ", loss)

# %%
try_parameters(200,500)
# Out:
# RMSE Loss:  4757.980240770584

# %%
try_parameters(200,450)
# Out:
# RMSE Loss:  4758.8439808877565

# %% [markdown]
# This is the lowest loss i can get by guessing..so for more optimize result we can use optimizer model

# %%
from sklearn.linear_model import SGDRegression
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 from sklearn.linear_model import SGDRegression
#
# ImportError: cannot import name 'SGDRegression' from 'sklearn.linear_model' (C:\Users\anupa\anaconda3\Lib\site-packages\sklearn\linear_model\__init__.py)

# %%
model = SGDRegression()

# %% [markdown]
# model.fit takes first parameter as 2d array and second result as 1d

# %%
inputs=non_smoker_df[['age']]
targets=non_smoker_df.charges
model.fit(inputs,targets)
# Out:
# LinearRegression()

# %%
predictions = model.predict(inputs)

# %%
predictions
# Out:
# array([2719.0598744 , 5391.54900271, 6727.79356686, ..., 2719.0598744 ,
#        2719.0598744 , 3520.80661289])

# %%
rmse(targets, predictions)
# Out:
# 4662.505766636395

# %%
model.coef_
# Out:
# array([267.24891283])

# %%
model.intercept_
# Out:
# -2091.4205565650827

# %%
try_parameters(model.coef_, model.intercept_)
# Out:
# RMSE Loss:  4662.505766636395

# %% [markdown]
# From start with following simple code we could,have achieved same results

# %%
# Create inputs and targets
inputs, targets = non_smoker_df[['age', 'bmi']], non_smoker_df['charges']

# Create and train the model
model = LinearRegression().fit(inputs, targets)

# Generate predictions
predictions = model.predict(inputs)

# Compute loss to evalute the model
loss = rmse(targets, predictions)
print('Loss:', loss)
# Out:
# Loss: 4662.3128354612945

# %%
inputs.shape
# Out:
# (1064, 2)
